# %%
# !pip3 install contextily
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: contextily in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (1.4.0)
# Requirement already satisfied: geopy in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (3.7.1)
# Requirement already satisfied: mercantile in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (9.3.0)
# Requirement already satisfied: rasterio in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (1.3.9)
# Requirement already satisfied: requests in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (2.28.2)
# Requirement already satisfied: joblib in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (1.2.0)
# Requirement already satisfied: xyzservices in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from contextily) (2023.10.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from mercantile->contextily) (8.1.7)
# Requirement already satisfied: affine in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from rasterio->contextily) (22.2.0)
# Requirement already satisfied: certifi in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from rasterio->contextily) (2022.9.24)
# Requirement already satisfied: cligj>=0.5 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from rasterio->contextily) (65.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from requests->contextily) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from requests->contextily) (1.26.12)
# Requirement already satisfied: colorama in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: C:\Users\Bartek\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from itertools import chain
from matplotlib import pyplot as plt
import pandas as pd
import geopandas as gpd
import random
from shapely.geometry import box, Point, LineString, Polygon, MultiPolygon, getx
import contextily as cx


BASEMAP_SOURCE = cx.providers.CartoDB.Positron
HEX_ALPHA = "4F"
POINT_PLOT_KWDS = {"marker": "D", "color": "black", "markersize": 20}
plt.rcParams['figure.dpi'] = 50
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 import geopandas as gpd
#       5 import random
# ----> 6 from shapely.geometry import box, Point, LineString, Polygon, MultiPolygon, getx
#       7 import contextily as cx
#      10 BASEMAP_SOURCE = cx.providers.CartoDB.Positron
#
# ImportError: cannot import name 'getx' from 'shapely.geometry' (C:\Users\Bartek\AppData\Local\Programs\Python\Python311\Lib\site-packages\shapely\geometry\__init__.py)

# %%
bbox = [19.909200668334964,50.06127149591537,19.92900609970093,50.072524465016656]  # bbox Berlin
minx, miny, maxx, maxy = bbox
poly_berlin = box(*bbox)

def random_coordinates(n, min_dist, max_dist):
    assert min_dist < max_dist # make sure parameters are valid

    coordinates = []
    for _ in range(n):
        counter = 0
        in_poly = False
        while not in_poly:
            counter += 1
            x = random.uniform(minx, maxx)
            y = random.uniform(miny, maxy)
            p = Point(x, y)
            if poly_berlin.contains(p):
                if coordinates:
                    if not min_dist < p.distance(Point(coordinates[-1])) < max_dist:
                        continue
                coordinates.append([x, y])
                in_poly = True
            if counter > 1000:
                raise ValueError("Distance settings are too restrictive. Try a wider range and remember it's in degrees.")

    return coordinates

# %%
route_amount = 100
input_pairs = [random_coordinates(n=2, min_dist=0.01, max_dist=0.02) for i in range(route_amount)]
print(input_pairs)

# %%
fig, ax = plt.subplots(1,1, figsize=(10,10))
img, ext = cx.bounds2img(*bbox, ll=True, source=BASEMAP_SOURCE)
_ = ax.imshow(img, extent=ext)

for pair in input_pairs:
    input_df = gpd.GeoDataFrame(geometry=[Point(x,y) for x,y in pair], crs="EPSG:4326").to_crs("EPSG:3857")
    input_df.plot(ax=ax, **POINT_PLOT_KWDS)

_ = ax.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 fig, ax = plt.subplots(1,1, figsize=(10,10))
# ----> 2 img, ext = cx.bounds2img(*bbox, ll=True, source=BASEMAP_SOURCE)
#       3 _ = ax.imshow(img, extent=ext)
#       5 for pair in input_pairs:
#
# NameError: name 'cx' is not defined

# %%
routers = {
    'graphhopper': {
        'api_key': 'a54e0dd9-06ab-4bb8-af69-102402242300',
        'display_name': 'GraphHopper',
        'profile': 'foot',
        'color': '#417900',
        'isochrones': True
    }
}

# %%
# !pip3 install routingpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting routingpy
#   Downloading routingpy-1.3.0-py3-none-any.whl (84 kB)
#                                               0.0/84.4 kB ? eta -:--:--
#      ---------------------------------------- 84.4/84.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20.0 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from routingpy) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20.0->routingpy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20.0->routingpy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20.0->routingpy) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bartek\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.20.0->routingpy) (2022.9.24)
# Installing collected packages: routingpy
# Successfully installed routingpy-1.3.0
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: C:\Users\Bartek\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from routingpy.routers import get_router_by_name

dict_ = {"router": [], "distance": [], "duration": []}
geometries = []
for router in routers:

    api = get_router_by_name(router)(api_key=routers[router]['api_key'])

    for coords_pair in input_pairs:

        # just from A to B without intermediate points
        route = api.directions(
            profile=routers[router]['profile'],
            locations=coords_pair
        )
        # Access the route properties with .geometry, .duration, .distance
        distance, duration = route.distance / 1000, int(route.duration / 60)
        dict_["router"].append(router)
        dict_["distance"].append(distance)
        dict_["duration"].append(duration)
        geometries.append(LineString(route.geometry,))

    print("Calulated {}".format(router))

routes_df = gpd.GeoDataFrame(dict_, geometry=geometries, crs="EPSG:4326").to_crs("EPSG:3857")
# Out:
# Calulated graphhopper

# %%
fig, axs = plt.subplots(3,2, figsize=(15,20))
img, ext = cx.bounds2img(*bbox, ll=True, source=BASEMAP_SOURCE)
for idx, router in enumerate(routers):
    ax = axs.flatten()[idx]
    _ = ax.imshow(img, extent=ext)
    routes_df.query(f"router == '{router}'").plot(
        ax=ax, linewidth=3,
        color=routers[router]["color"]
    )
    for pair in input_pairs:
        input_df = gpd.GeoDataFrame(geometry=[Point(x,y) for x,y in pair], crs="EPSG:4326").to_crs("EPSG:3857")
        input_df.plot(ax=ax, **POINT_PLOT_KWDS)

    _ = ax.axis("off")
    ax.set_title(routers[router]['display_name'])

fig.tight_layout()

# %%
for pair in input_pairs:
    input_df = gpd.GeoDataFrame(geometry=[Point(x,y) for x,y in pair], crs="EPSG:4326").to_crs("EPSG:3857")
    print(routes_df['geometry'])
    print(pair)
# Out:
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.909752521842705, 50.06458731448392], [19.9236144205769, 50.06730564524679]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.926073537084466, 50.06285445154416], [19.915850575479855, 50.06951038810482]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.92102585711329, 50.07004055750952], [19.90950427915937, 50.06700586917975]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.924169519125066, 50.068229715589084], [19.911282903615554, 50.06167109028227]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.91987500524845, 50.06705350677597], [19.91095947525233, 50.06209962460569]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.927417628731693, 50.07170375494093], [19.911058704964802, 50.06778689851193]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.91291953037574, 50.06819504257169], [19.92731669096866, 50.06356200587496]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.919770226943584, 50.07113964511392], [19.9110927879615, 50.063186581917044]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.909988706455753, 50.07002781970116], [19.923780806634056, 50.06481252060576]]
# 0    LINESTRING (2216344.345 6457472.683, 2216208.5...
# 1    LINESTRING (2218161.079 6457165.743, 2218210.0...
# 2    LINESTRING (2217596.689 6458414.382, 2217586.6...
# 3    LINESTRING (2217933.987 6458091.799, 2217947.3...
# 4    LINESTRING (2217470.898 6457897.562, 2217514.3...
# 5    LINESTRING (2218310.247 6458704.024, 2218227.8...
# 6    LINESTRING (2216692.775 6458090.065, 2216736.1...
# 7    LINESTRING (2217464.219 6458601.694, 2217446.4...
# 8    LINESTRING (2216365.496 6458390.101, 2216282.0...
# 9    LINESTRING (2217154.751 6457401.583, 2217188.1...
# Name: geometry, dtype: geometry
# [[19.91702378505565, 50.064303064013], [19.927293633268864, 50.06336467680915]]

# %%
from datetime import datetime, timedelta
import random

routes_df_wcf = gpd.GeoDataFrame(dict_, geometry=geometries)

outputData = pd.DataFrame(columns = ["time","longitude","latitude"])

for route in routes_df_wcf['geometry']:
    l = route.length + 0.0001
    start_datetime = datetime(2023, 12, 10, 17, 50) + timedelta(seconds=random.randrange(0, 1200))
    for dist in np.arange(0, l, 0.0001):
        currentLoc = route.interpolate(dist)
        outputData.loc[len(outputData.index)] = [start_datetime + timedelta(seconds=dist*100000), currentLoc.x, currentLoc.y]

# %%
outputData.to_csv("routes_multiple.csv")

# %%
outputData
# Out:
#                     time  longitude   latitude
# 0    2023-12-10 17:55:39  19.909760  50.064610
# 1    2023-12-10 17:55:49  19.909661  50.064626
# 2    2023-12-10 17:55:59  19.909563  50.064642
# 3    2023-12-10 17:56:09  19.909464  50.064659
# 4    2023-12-10 17:56:19  19.909365  50.064675
# ...                  ...        ...        ...
# 1704 2023-12-10 18:13:45  19.927008  50.063162
# 1705 2023-12-10 18:13:55  19.927105  50.063189
# 1706 2023-12-10 18:14:05  19.927201  50.063216
# 1707 2023-12-10 18:14:15  19.927297  50.063243
# 1708 2023-12-10 18:14:25  19.927360  50.063260
#
# [1709 rows x 3 columns]

# %%
import numpy as np
from scipy.interpolate import interp1d

data = [
    [19.914242, 50.06847],
    [19.91461, 50.06843],
    [19.914668, 50.068027],
    [19.914696, 50.067962],
    [19.914911, 50.067698],
    [19.914899, 50.067664],
    [19.915102, 50.06764],
    [19.91561, 50.067625],
    [19.917633, 50.067716],
    [19.918039, 50.067686],
    [19.917962, 50.067534],
    [19.918093, 50.067522],
    [19.918016, 50.067439],
    [19.917884, 50.067197],
    [19.918095, 50.067147],
    [19.918113, 50.067181]
]
data = route_geo[0]
print(data)

# Separate latitude and longitude
longitude, latitude = zip(*data)

# Create an interpolation function for latitude
interp_latitude = interp1d(longitude, latitude, kind='linear', fill_value='extrapolate')

# Generate more new longitude values for interpolation
new_longitude = np.linspace(min(longitude), max(longitude), 500)

# Perform interpolation
new_latitude = interp_latitude(new_longitude)

data = []
# Print the latitude and longitude of the interpolated points
for lon, lat in zip(new_longitude, new_latitude):
    print(f"[{lon}, {lat}]")
    data.append([lon, lat])
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 22
#       2 from scipy.interpolate import interp1d
#       4 data = [
#       5     [19.914242, 50.06847],
#       6     [19.91461, 50.06843],
#    (...)
#      20     [19.918113, 50.067181]
#      21 ]
# ---> 22 data = route_geo[0]
#      23 print(data)
#      25 # Separate latitude and longitude
#
# NameError: name 'route_geo' is not defined

# %%
import pandas as pd
from datetime import datetime, timedelta


# Convert your data to a pandas DataFrame
df = pd.DataFrame(data, columns=["Latitude", "Longitude"])

# Set the start datetime
start_datetime = datetime(2023, 12, 10, 20, 0)

# Calculate the time difference between each point
time_difference = timedelta(minutes=5) / len(df)

# Add the datetime column
df["Datetime"] = [start_datetime + i * time_difference for i in range(len(df))]

# Print the resulting DataFrame
print(df)

df.to_csv('points.csv', index=False)
# Out:
#       Latitude  Longitude                Datetime
# 0    19.914242  50.068470 2023-12-10 20:00:00.000
# 1    19.914250  50.068469 2023-12-10 20:00:00.600
# 2    19.914258  50.068468 2023-12-10 20:00:01.200
# 3    19.914265  50.068467 2023-12-10 20:00:01.800
# 4    19.914273  50.068467 2023-12-10 20:00:02.400
# ..         ...        ...                     ...
# 495  19.918082  50.067555 2023-12-10 20:04:57.000
# 496  19.918090  50.067532 2023-12-10 20:04:57.600
# 497  19.918097  50.067152 2023-12-10 20:04:58.200
# 498  19.918105  50.067166 2023-12-10 20:04:58.800
# 499  19.918113  50.067181 2023-12-10 20:04:59.400
#
# [500 rows x 3 columns]
